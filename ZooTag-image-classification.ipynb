# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np, matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

DATA_ROOT = "/content/drive/MyDrive/Lab19_images"
IMG_SIZE  = (224, 224)
BATCH     = 32
SEED      = 1337
AUTOTUNE  = tf.data.AUTOTUNE

# 80/20 split from the UNSPLIT directory
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATA_ROOT,
    image_size=IMG_SIZE,
    batch_size=BATCH,
    shuffle=True,
    seed=SEED,
    validation_split=0.2,
    subset="training")

valtest_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATA_ROOT,
    image_size=IMG_SIZE,
    batch_size=BATCH,
    shuffle=True,
    seed=SEED,
    validation_split=0.2,
    subset="validation")

# split the 20% into 10% val + 10% test
valtest_count = tf.data.experimental.cardinality(valtest_ds).numpy()
test_ds = valtest_ds.take(max(1, valtest_count // 2))
val_ds = valtest_ds.skip(max(1, valtest_count // 2))

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

def format_example(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def augment_example(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_contrast(image, 0.9, 1.1)
    return image, label

# Apply preprocessing
train_ds = train_ds.map(format_example, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(format_example,   num_parallel_calls=AUTOTUNE)
test_ds = test_ds.map(format_example,  num_parallel_calls=AUTOTUNE)

# Add augmentation to training only
train_ds = train_ds.map(augment_example, num_parallel_calls=AUTOTUNE)

# Cache & prefetch for speed
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)
# Out:
# Found 1220 files belonging to 7 classes.
# Using 976 files for training.
# Found 1220 files belonging to 7 classes.
# Using 244 files for validation.
# Classes: ['AMPHIBIAN', 'BIRD', 'FISH', 'INSECT', 'MAMMAL', 'MARINE_INVERTEBRATE', 'REPTILE']

# %%
base = tf.keras.applications.MobileNetV2(
    input_shape=IMG_SIZE+(3,), include_top=False, weights='imagenet')
base.trainable = False  # stage 1

model = models.Sequential([
    base,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)
hist_head = model.fit(train_ds, validation_data=val_ds, epochs=10, callbacks=[early])

# fine-tune last ~21 layers
base.trainable = True
for layer in base.layers[:-21]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
hist_ft = model.fit(train_ds, validation_data=val_ds, epochs=10, callbacks=[early])
# Out:
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 98s 3s/step - accuracy: 0.2412 - loss: 2.0796 - val_accuracy: 0.7328 - val_loss: 0.8449
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.6692 - loss: 0.8769 - val_accuracy: 0.7931 - val_loss: 0.5549
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 29s 932ms/step - accuracy: 0.7871 - loss: 0.5902 - val_accuracy: 0.8276 - val_loss: 0.4697
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 28s 921ms/step - accuracy: 0.8286 - loss: 0.4732 - val_accuracy: 0.8621 - val_loss: 0.4135
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8590 - loss: 0.4006 - val_accuracy: 0.8534 - val_loss: 0.3820
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 39s 956ms/step - accuracy: 0.8733 - loss: 0.3667 - val_accuracy: 0.8276 - val_loss: 0.3705
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 31s 984ms/step - accuracy: 0.9054 - loss: 0.3015 - val_accuracy: 0.8103 - val_loss: 0.3702
# Epoch 8/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 39s 946ms/step - accuracy: 0.9163 - loss: 0.2691 - val_accuracy: 0.8448 - val_loss: 0.3513
# Epoch 9/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 27s 885ms/step - accuracy: 0.9124 - loss: 0.2620 - val_accuracy: 0.8362 - val_loss: 0.3410
# Epoch 10/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9423 - loss: 0.2268 - val_accuracy: 0.8448 - val_loss: 0.3312
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.8159 - loss: 0.4965 - val_accuracy: 0.8621 - val_loss: 0.3174
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9824 - loss: 0.0967 - val_accuracy: 0.8621 - val_loss: 0.2926
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9975 - loss: 0.0439 - val_accuracy: 0.8707 - val_loss: 0.2839
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 1.0000 - loss: 0.0289 - val_accuracy: 0.8707 - val_loss: 0.2857
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.8793 - val_loss: 0.2901
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9998 - loss: 0.0121 - val_accuracy: 0.8793 - val_loss: 0.3013

# %%
import numpy as np, tensorflow as tf, matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# 1) Evaluate on the test set
loss, acc = model.evaluate(test_ds)
print(f"Test accuracy: {acc: }")

# 2) Get predictions + true labels
y_true = tf.concat([y for _, y in test_ds], axis=0).numpy()
y_prob = model.predict(test_ds, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

# 3) Confusion matrix —
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, colorbar=False)
plt.title("Confusion Matrix for Transfer Learning Model")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 4) Per-class metrics (precision/recall/F1)
print("Classification report:\n")
print(classification_report(y_true, y_pred, target_names=class_names, digits=3))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.8771 - loss: 0.2414
# Test accuracy:  0.859375
# Classification report:
#
#                      precision    recall  f1-score   support
#
#           AMPHIBIAN      0.733     0.846     0.786        13
#                BIRD      0.846     1.000     0.917        22
#                FISH      0.818     0.900     0.857        20
#              INSECT      1.000     0.944     0.971        18
#              MAMMAL      0.957     0.880     0.917        25
# MARINE_INVERTEBRATE      0.833     0.667     0.741        15
#             REPTILE      0.769     0.667     0.714        15
#
#            accuracy                          0.859       128
#           macro avg      0.851     0.843     0.843       128
#        weighted avg      0.863     0.859     0.857       128

# %%
# ----- From Tess

# Save keras model

h5_path = "/content/drive/MyDrive/Lab19_model.keras"
model.save(h5_path)
print("Saved!", h5_path)

# --- Convert to TFLITE

converter = tf.lite.TFLiteConverter.from_keras_model(model)

# --- optimizes the size and performance
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# --- makes the model smaller, faster gpu but gives the same result
converter.target_spec.supported_types = [tf.float16]

# -- convert the model

tflite_model = converter.convert()

# -- save the model as a file

tflite_path = "/content/drive/MyDrive/Lab19_model.tflite"
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)
print("Saved!", tflite_path)

# --- load thee model to verify it works

interpreter = tf.lite.Interpreter(model_path=tflite_path)
# - prep the model to be able to run redictions
interpreter.allocate_tensors()
# get details aabout the input and output, ex. foramtting or size
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Inputs:", input_details)
print("Outputs:", output_details)
#prints if its successfull
print("TFLite model loaded successfully")
# Out:
# Saved! /content/drive/MyDrive/Lab19_model.keras
# Saved artifact at '/tmp/tmpdqamci5m'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   133208900445840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900446224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900448528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900448144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900447568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900446032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900448720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900449488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900449104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900446416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900448336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900450640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900450832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900447952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900447760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900451408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898979024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133211077531152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900451984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208900452176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898980368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898980560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898979792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898979408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898979600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898978832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898977872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898979984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898981520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898980944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898981328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898980176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898982480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898981904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898982096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898982288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898978064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898983440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898983824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898984016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898983056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898983632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898984592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898984976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898985168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898984208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898984784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898985744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898983248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898985360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898985552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898982672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898986704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898986128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898986320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898986512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898982864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898987664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898987088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898987280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898987472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898984400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898988624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898988048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898988240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898988432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898985936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898989584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898989008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898989200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898989392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898986896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898990544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898989968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898990160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898990352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898987856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898991504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898990928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898991120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898991312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898988816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898992464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898991888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898992080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898992272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898989776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898993424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898992848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898993040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898993616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898994000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898992656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898991696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898993232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899716304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898993808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898990736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899715344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899715728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899715920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899716112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899717264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899716688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899716880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899717072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899715152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899718224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899717648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899717840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899718032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899715536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899719184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899718608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899718800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899718992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899716496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899720144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899719568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899719952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899717456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899721104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899720528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899720720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899720912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899718416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899722064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899721488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899721680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899721872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899719376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899723024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899722448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899722640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899722832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899720336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899723984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899723408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899723600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899723792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899721296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899724944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899724368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899724560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899724752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899722256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899725904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899725328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899725520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899725712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899723216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899726864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899726288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899726480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899726672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899724176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899727824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899727248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899727440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899727632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899725136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899728784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899728208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899728400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899728592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899726096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899729744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899729168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899729360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899729552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899727056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899730704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899730128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899730320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899730896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899731280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899729936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899730512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898520272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899731088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208899728016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898519312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898519696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898519888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898520080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898521232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898520656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898520848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898521040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898519120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898522192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898521616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898521808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898522000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898519504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898523152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898522576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898522768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898522960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898520464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898524112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898523536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898523728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898523920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898521424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898525072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898524496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898524688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898524880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898522384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898526032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898525456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898525648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898525840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898523344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898526992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898526416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898526608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898526800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898524304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898527952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898527376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898527568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898527760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898525264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898528912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898528336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898528528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898528720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898526224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898529872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898529296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898529488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898529680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898527184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898530832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898530256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898530448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898530640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898528144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898531792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898531216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898531408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898531600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898529104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898532752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898532176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898532368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898532560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898530064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898533712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898533136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898533328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898533520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898531024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898534672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898531984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133208898535248: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved! /content/drive/MyDrive/Lab19_model.tflite
# Inputs: [{'name': 'serving_default_keras_tensor_154:0', 'index': 0, 'shape': array([  1, 224, 224,   3], dtype=int32), 'shape_signature': array([ -1, 224, 224,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Outputs: [{'name': 'StatefulPartitionedCall_1:0', 'index': 278, 'shape': array([1, 7], dtype=int32), 'shape_signature': array([-1,  7], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# TFLite model loaded successfully
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

import tensorflow.lite as tflite

# Load the saved TFLite model
tflite_path = "/content/drive/MyDrive/Lab19_model.tflite"

interpreter = tflite.Interpreter(model_path=tflite_path)

# -- initiate the model so it can recieve dataa
interpreter.allocate_tensors()

# fetch info about input and output
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Model loaded")
print("Inputs:", input_details[0]['shape'])
print("Outputs:", output_details[0]['shape'])

# - fetch a small sample set batch with images and labels and takes the 7 first images to show example.

for images, labels in test_ds.take(1): #sample_images, sample_labels = list(test_ds.take(1))[0] works aswell.
    sample_images = images[:7].numpy()
    sample_labels = labels[:7].numpy()
    print("Saved class names:", class_names)

# --- function makes a prediction with tflite model for one picture
def predict_tflite_image(image):
    # Expand to batch dimension and convert to float 32
    image = np.expand_dims(image, axis=0).astype(np.float32)

    # send the picture to the model
    interpreter.set_tensor(input_details[0]['index'], image)

    # run the model (prediction)
    interpreter.invoke()

    # get the result
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # removes unneccissary dimensions. aand reutrns classs predictions
    return np.squeeze(output_data)

# # "draw" the iamges with models predictions
plt.figure(figsize=(14, 4))
for i, img in enumerate(sample_images):
    preds = predict_tflite_image(img)
    pred_class = np.argmax(preds)
    true_class = sample_labels[i]

    plt.subplot(1, 7, i + 1)
    plt.imshow(np.clip(img, 0, 1)) #securing the image value 0.1
    plt.title(f"Pred: {class_names[pred_class]}\nTrue: {class_names[true_class]}")
    plt.axis('off')

plt.tight_layout()
plt.show()

keras_preds = np.argmax(model.predict(sample_images), axis=1) #running the original model keras on the same images
#--- counts the tflite pred and prints out keras and tflite
print("Comparision keras vs TFLite: ")
for i in range(len(sample_images)):
    tflite_pred = np.argmax(predict_tflite_image(sample_images[i]))
    print (f"Image {i+1}: Keras= {class_names[keras_preds[i]]},TFLite={class_names[tflite_pred]}")
# Out:
# Model loaded
# Inputs: [  1 224 224   3]
# Outputs: [1 7]
# Saved class names: ['AMPHIBIAN', 'BIRD', 'FISH', 'INSECT', 'MAMMAL', 'MARINE_INVERTEBRATE', 'REPTILE']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Comparision keras vs TFLite:
# Image 1: Keras= BIRD,TFLite=BIRD
# Image 2: Keras= INSECT,TFLite=INSECT
# Image 3: Keras= MAMMAL,TFLite=MAMMAL
# Image 4: Keras= BIRD,TFLite=BIRD
# Image 5: Keras= FISH,TFLite=FISH
# Image 6: Keras= MARINE_INVERTEBRATE,TFLite=MARINE_INVERTEBRATE
# Image 7: Keras= BIRD,TFLite=BIRD
